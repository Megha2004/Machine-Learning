# %% [markdown]
# <a href="https://colab.research.google.com/github/Megha2004/Machine-Learning/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# Load breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the neural network architecture
model = Sequential([
    Dense(10, input_dim=30, activation='relu'),
    Dense(5, activation='softmax'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training set
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=100, batch_size=10)

# Predict the output for the testing set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

# Calculate the accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Visualize the neural network architecture
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
Image(filename='model.png')
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 6ms/step - loss: 0.6922 - accuracy: 0.3934 - val_loss: 0.7311 - val_accuracy: 0.2895
# Epoch 2/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6680 - accuracy: 0.3934 - val_loss: 0.6982 - val_accuracy: 0.2895
# Epoch 3/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6415 - accuracy: 0.3934 - val_loss: 0.6746 - val_accuracy: 0.2895
# Epoch 4/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.3934 - val_loss: 0.6695 - val_accuracy: 0.2895
# Epoch 5/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6174 - accuracy: 0.5473 - val_loss: 0.6307 - val_accuracy: 0.9035
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.8593 - val_loss: 0.5932 - val_accuracy: 0.9035
# Epoch 7/100
# ...
